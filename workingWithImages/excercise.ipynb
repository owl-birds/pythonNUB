# %% [markdown]
# # EXCERCISE

# %%
from PIL import Image

# %%
import os
dir = os.getcwdb()
dir
# Out:
# b'c:\\Users\\GL503GE\\Desktop\\notebook J\\CSES\\workingWithImages'

# %%
dir = "c:\\Users\\GL503GE\\Desktop\\notebook J\\CSES\\workingWithImages\\images\\"
dir
# Out:
# 'c:\\Users\\GL503GE\\Desktop\\notebook J\\CSES\\workingWithImages\\images\\'

# %%
mask = Image.open(dir+"mask.png")

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251 at 0x1868AAD3370>

# %%
wordMatrix = Image.open(dir+"wordMatrix.png")

# %%
wordMatrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x1868AAD3220>

# %%
print(mask.size)
print(wordMatrix.size)
# Out:
# (505, 251)
# (1015, 559)

# %%
mask = mask.resize((1015,559))
mask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x18689951FD0>

# %%
print(mask.size)
print(wordMatrix.size)
# Out:
# (1015, 559)
# (1015, 559)

# %%
mask.putalpha(100)
mask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x18689951FD0>

# %%
wordMatrix.paste(im=mask,box=(0,0),mask=mask)

# %%
wordMatrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x1868AAD3220>
